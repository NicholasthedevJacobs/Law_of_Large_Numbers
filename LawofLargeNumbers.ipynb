# %%
import numpy as np
from numpy.random import randn

counter = 0
sample_size = 100

for i in randn(sample_size):
    if i > -1 and i < 1:
        counter += 1

answer = counter / sample_size

print(answer)
# Out:
# 0.68
